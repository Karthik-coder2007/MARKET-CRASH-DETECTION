# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik-coder2007/MARKET-CRASH-DETECTION/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install yfinance

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

plt.style.use('seaborn-v0_8')

# %%
# Download data
df = yf.download("^GSPC", start="2010-01-01", end="2026-01-01")

# Reset index
df.reset_index(inplace=True)

# Show first rows
df.head()
# Out:
# /tmp/ipykernel_3883/2801129336.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("^GSPC", start="2010-01-01", end="2026-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price        Date        Close         High          Low         Open  \
# Ticker                   ^GSPC        ^GSPC        ^GSPC        ^GSPC
# 0      2010-01-04  1132.989990  1133.869995  1116.560059  1116.560059
# 1      2010-01-05  1136.520020  1136.630005  1129.660034  1132.660034
# 2      2010-01-06  1137.140015  1139.189941  1133.949951  1135.709961
# 3      2010-01-07  1141.689941  1142.459961  1131.319946  1136.270020
# 4      2010-01-08  1144.979980  1145.390015  1136.219971  1140.520020
#
# Price       Volume
# Ticker       ^GSPC
# 0       3991400000
# 1       2491020000
# 2       4972660000
# 3       5270680000
# 4       4389590000

# %%
df.tail()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker                   ^GSPC        ^GSPC        ^GSPC        ^GSPC
# 4019   2025-12-24  6932.049805  6937.319824  6904.910156  6904.910156
# 4020   2025-12-26  6929.939941  6945.770020  6921.600098  6936.020020
# 4021   2025-12-29  6905.740234  6920.209961  6888.759766  6903.600098
# 4022   2025-12-30  6896.240234  6913.250000  6893.470215  6900.439941
# 4023   2025-12-31  6845.500000  6901.419922  6844.549805  6898.819824
#
# Price       Volume
# Ticker       ^GSPC
# 4019    1798270000
# 4020    2586550000
# 4021    3541750000
# 4022    3309930000
# 4023    3261830000

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Date              0
# Close   ^GSPC     0
# High    ^GSPC     0
# Low     ^GSPC     0
# Open    ^GSPC     0
# Volume  ^GSPC     0
# dtype: int64

# %%
df.describe()
# Out:
# Price                            Date        Close         High          Low  \
# Ticker                                       ^GSPC        ^GSPC        ^GSPC
# count                            4024  4024.000000  4024.000000  4024.000000
# mean    2017-12-30 13:02:58.926441216  2945.011381  2960.069326  2927.577092
# min               2010-01-04 00:00:00  1022.580017  1032.949951  1010.909973
# 25%               2014-01-01 12:00:00  1805.630035  1810.665009  1800.722504
# 50%               2017-12-28 12:00:00  2584.730103  2595.869995  2571.649902
# 75%               2021-12-28 06:00:00  4078.204956  4098.564941  4052.197571
# max               2025-12-31 00:00:00  6932.049805  6945.770020  6921.600098
# std                               NaN  1491.073720  1498.338506  1482.912188
#
# Price          Open        Volume
# Ticker        ^GSPC         ^GSPC
# count   4024.000000  4.024000e+03
# mean    2944.412381  4.012348e+09
# min     1027.650024  0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Date, )         4024 non-null   datetime64[ns]
#  1   (Close, ^GSPC)   4024 non-null   float64
#  2   (High, ^GSPC)    4024 non-null   float64
#  3   (Low, ^GSPC)     4024 non-null   float64
#  4   (Open, ^GSPC)    4024 non-null   float64
#  5   (Volume, ^GSPC)  4024 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 188.8 KB

# %%
df1 = yf.download("AAPL", start="2010-01-01", end="2026-01-01")
# Out:
# /tmp/ipykernel_3883/2179543990.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df1 = yf.download("AAPL", start="2010-01-01", end="2026-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
df1.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.412384  6.427065  6.363544  6.395005  493729600
# 2010-01-05  6.423471  6.459726  6.389612  6.430063  601904800
# 2010-01-06  6.321297  6.448939  6.314705  6.423470  552160000
# 2010-01-07  6.309609  6.352157  6.263766  6.344667  477131200
# 2010-01-08  6.351558  6.352158  6.264067  6.301220  447610800

# %%
# Calculate daily returns
df['Returns'] = df['Close'].pct_change()

# Drop missing values
df.dropna(inplace=True)

df.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker                   ^GSPC        ^GSPC        ^GSPC        ^GSPC
# 1      2010-01-05  1136.520020  1136.630005  1129.660034  1132.660034
# 2      2010-01-06  1137.140015  1139.189941  1133.949951  1135.709961
# 3      2010-01-07  1141.689941  1142.459961  1131.319946  1136.270020
# 4      2010-01-08  1144.979980  1145.390015  1136.219971  1140.520020
# 5      2010-01-11  1146.979980  1149.739990  1142.020020  1145.959961
#
# Price       Volume   Returns
# Ticker       ^GSPC
# 1       2491020000  0.003116
# 2       4972660000  0.000546
# 3       5270680000  0.004001
# 4       4389590000  0.002882
# 5       4255780000  0.001747

# %%
def cusum_detection(returns, threshold=0.02, drift=0.001):
    """
    CUSUM for detecting downward market crashes
    """
    s_neg = [0]
    signals = [False]

    mean = returns.mean()

    for i in range(1, len(returns)):
        r = returns.iloc[i]

        s_new = min(0, s_neg[-1] + (r - mean - drift))
        s_neg.append(s_new)

        # Crash signal
        if s_new < -threshold:
            signals.append(True)
        else:
            signals.append(False)

    return np.array(s_neg), np.array(signals)

# %%
df['CUSUM'], df['Crash'] = cusum_detection(df['Returns'])

print("Total crashes detected:", df['Crash'].sum())
# Out:
# Total crashes detected: 4012

# %%
plt.figure(figsize=(14,6))

# Plot price
plt.plot(df['Date'], df['Close'], label='S&P 500 Price')

# Highlight crashes
crashes = df[df['Crash'] == True]
plt.scatter(crashes['Date'], crashes['Close'],
            color='red', label='Crash Detected')

plt.title("Market Crash Detection using CUSUM")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))

plt.plot(df['Date'], df['CUSUM'], label='CUSUM')
plt.axhline(-0.02, color='red', linestyle='--', label='Threshold')

plt.title("CUSUM Chart (Crash Detection)")
plt.legend()
plt.show()

# %%
crash_dates = df[df['Crash'] == True][['Date', 'Close']]
crash_dates.tail(10)
# Out:
# Price        Date        Close
# Ticker                   ^GSPC
# 4014   2025-12-17  6721.430176
# 4015   2025-12-18  6774.759766
# 4016   2025-12-19  6834.500000
# 4017   2025-12-22  6878.490234
# 4018   2025-12-23  6909.790039
# 4019   2025-12-24  6932.049805
# 4020   2025-12-26  6929.939941
# 4021   2025-12-29  6905.740234
# 4022   2025-12-30  6896.240234
# 4023   2025-12-31  6845.500000

# %%
# Filter only strong crash signals (avoid too many points)
major_crashes = df[(df['Crash'] == True) & (df['Returns'] < -0.02)]

plt.figure(figsize=(14,6))
plt.plot(df['Date'], df['Close'], label='Price')

plt.scatter(major_crashes['Date'], major_crashes['Close'],
            color='red', label='Major Crash')

plt.title("Major Crash Detection (Filtered)")
plt.legend()
plt.show()

# %%
df['Month'] = df['Date'].dt.to_period('M')

monthly_crashes = df[df['Crash'] == True].groupby('Month').size()

monthly_crashes.plot(kind='bar', figsize=(12,5))
plt.title("Monthly Crash Frequency")
plt.show()

# %%
df['Volatility'] = df['Returns'].rolling(20).std()

plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Volatility'])
plt.title("Market Volatility")
plt.show()

# %%
df['Target'] = df['Crash'].astype(int)

# %%
vol_threshold = df['Volatility'].mean() + df['Volatility'].std()

df['Risk_Level'] = "Low"

df.loc[df['Crash'], 'Risk_Level'] = "Medium"
df.loc[(df['Crash']) & (df['Volatility'] > vol_threshold), 'Risk_Level'] = "High"

df[['Date','Risk_Level']].tail()
# Out:
# Price        Date Risk_Level
# Ticker
# 4019   2025-12-24     Medium
# 4020   2025-12-26     Medium
# 4021   2025-12-29     Medium
# 4022   2025-12-30     Medium
# 4023   2025-12-31     Medium

# %%
crash_days = df[df['Crash']]

for idx in crash_days.index[:3]:
    print("Crash Date:", df.loc[idx, 'Date'])
    print("Return:", df.loc[idx, 'Returns'])
    print("Volatility:", df.loc[idx, 'Volatility'])
    print("------")
# Out:
# Crash Date: Ticker
#     2010-01-21 00:00:00
# Name: 12, dtype: object
# Return: Ticker
#    -0.018945
# Name: 12, dtype: object
# Volatility: Ticker
#     NaN
# Name: 12, dtype: object
# ------
# Crash Date: Ticker
#     2010-01-22 00:00:00
# Name: 13, dtype: object
# Return: Ticker
#    -0.022141
# Name: 13, dtype: object
# Volatility: Ticker
#     NaN
# Name: 13, dtype: object
# ------
# Crash Date: Ticker
#     2010-01-25 00:00:00
# Name: 14, dtype: object
# Return: Ticker
#     0.004598
# Name: 14, dtype: object
# Volatility: Ticker
#     NaN
# Name: 14, dtype: object
# ------

# %%
# Download NASDAQ data
nasdaq = yf.download("^IXIC", start="2010-01-01", end="2024-01-01")

nasdaq.reset_index(inplace=True)

# Calculate returns
nasdaq['Returns'] = nasdaq['Close'].pct_change()

nasdaq.dropna(inplace=True)
# Out:
# /tmp/ipykernel_3883/3741776274.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nasdaq = yf.download("^IXIC", start="2010-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
# Apply CUSUM on NASDAQ
nasdaq['CUSUM'], nasdaq['Crash'] = cusum_detection(nasdaq['Returns'])

print("NASDAQ crashes:", nasdaq['Crash'].sum())
# Out:
# NASDAQ crashes: 3512

# %%
plt.figure(figsize=(14,6))

# Plot both indices
plt.plot(df['Date'], df['Close'], label='S&P 500')
plt.plot(nasdaq['Date'], nasdaq['Close'], label='NASDAQ')

plt.title("Market Comparison")
plt.legend()
plt.show()

# %%
# Extract crash dates
sp_crashes = df[df['Crash']]['Date']
nasdaq_crashes = nasdaq[nasdaq['Crash']]['Date']

# Find common crash dates
common_crashes = set(sp_crashes).intersection(set(nasdaq_crashes))

print("Common crash dates:", list(common_crashes)[:10])
# Out:
# Common crash dates: [Timestamp('2023-06-29 00:00:00'), Timestamp('2015-12-30 00:00:00'), Timestamp('2019-02-15 00:00:00'), Timestamp('2014-10-21 00:00:00'), Timestamp('2013-01-04 00:00:00'), Timestamp('2019-05-09 00:00:00'), Timestamp('2015-03-18 00:00:00'), Timestamp('2011-12-15 00:00:00'), Timestamp('2013-10-23 00:00:00'), Timestamp('2020-09-18 00:00:00')]

# %%
# Major crashes for S&P 500
sp_major = df[df['Returns'] < -0.03]

# Major crashes for NASDAQ
nasdaq_major = nasdaq[nasdaq['Returns'] < -0.03]

# %%
plt.figure(figsize=(14,6))

# Plot prices
plt.plot(df['Date'], df['Close'], label='S&P 500')
plt.plot(nasdaq['Date'], nasdaq['Close'], label='NASDAQ')

# Major crashes S&P
plt.scatter(sp_major['Date'],
            sp_major['Close'],
            color='red', label='S&P Major Crash')

# Major crashes NASDAQ
plt.scatter(nasdaq_major['Date'],
            nasdaq_major['Close'],
            color='black', label='NASDAQ Major Crash')

plt.legend()
plt.title("Major Market Crashes Comparison")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
# Clean data
df = df.dropna()

# Predict future crash (IMPORTANT)
df['Target'] = (df['Returns'].shift(-1) < -0.02).astype(int)

df = df.dropna()

# Features
X = df[['Returns', 'Volatility', 'CUSUM']]
y = df['Target']

# Split (time-series safe)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# Model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9812734082397003
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       786
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.98       801
#    macro avg       0.49      0.50      0.50       801
# weighted avg       0.96      0.98      0.97       801
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
